# %%
from sqlalchemy import create_engine
ip = 'localhost'
port = 3306
username = 'root'
passo = 'root'
URL = 'mysql+pymysql://{}:{}@{}:{}/{}?charset=utf8mb4'.format(username, passo, ip,port,'db_name')
engine = create_engine(URL, encoding='utf-8')
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\ASUS\anaconda3\envs\RS_gradProject\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# c:\Users\ASUS\anaconda3\envs\RS_gradProject\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# c:\Users\ASUS\anaconda3\envs\RS_gradProject\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# c:\Users\ASUS\anaconda3\envs\RS_gradProject\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# ...
